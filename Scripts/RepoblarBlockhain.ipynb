# %%
from pymongo import MongoClient
import requests
import time

con = MongoClient('mongodb://admin:J5B3NAzXttzS@35.180.134.166:27017/?authSource=CUN&readPreference=primary&appname=MongoDB%20Compass&ssl=false')
db = con['Secretos']
collection = db.secretos
cursor = collection.find({})
#Prep para el request
url="http://15.236.39.73:8081/secrets"
for a in cursor:
    data={"id":a["_id"],
    "description": a["description"],
    "file": a["file"],
    "filename": a["filename"],
    "user": a["user"],
    "userArea": a["userArea"],
    "userLevel": a["userLevel"],
    "fecha":a["createdAt"],
    "project":a["project"], 
    "userCompany": a["userCompany"],
    "metadata": a["metadata"],
     "surveys":a["surveys"],}
    b=len(bson.BSON.encode(a))
    if b < 10000000:
        response = requests.post(url, json=data)
        print(response)
        time.sleep(0.1) # Sleep for 3 seconds
    else:
        print("Fichero demasiado grande: "+str(b))
# Out:
# <Response [201]>
# <Response [201]>
# <Response [201]>
# <Response [201]>
# <Response [201]>
# <Response [201]>
# <Response [201]>
# <Response [201]>
# <Response [201]>
# <Response [201]>
# <Response [201]>
# <Response [201]>
# <Response [201]>
# <Response [201]>
# <Response [201]>
# <Response [201]>
# <Response [201]>
# <Response [201]>
# <Response [201]>
# <Response [201]>
# <Response [201]>
# <Response [201]>
# <Response [201]>
# <Response [201]>
# <Response [201]>
# <Response [201]>
# <Response [201]>
# <Response [201]>
# <Response [201]>
# <Response [201]>
# <Response [201]>
# <Response [201]>
# <Response [201]>
# <Response [201]>
# <Response [201]>
# <Response [201]>
# <Response [201]>
# <Response [201]>
# <Response [201]>
# <Response [201]>
# <Response [201]>
# <Response [201]>
# <Response [201]>
# <Response [201]>
# <Response [201]>
# <Response [201]>
# <Response [201]>
# <Response [201]>
# <Response [201]>
# <Response [201]>
# <Response [201]>
# ...

# %%
from pymongo import MongoClient
import requests
import time

con = MongoClient('mongodb://admin:J5B3NAzXttzS@35.180.134.166:27017/?authSource=CUN&readPreference=primary&appname=MongoDB%20Compass&ssl=false')
db = con['Secretos']
collection = db.logs
cursor = collection.find({})
#Prep para el request
url="http://15.236.39.73:8081/logs"
for a in cursor:
    data={
    "id":a["_id"],
    "fecha":a["createdAt"],
    "user": a["user"],
    "userArea": a["userArea"],
    "userLevel": a["userLevel"],
    "userCompany": a["userCompany"],
    "secret":a["secret"],
    "action":a["action"],}
    if a["_id"] != "51012cb0-5385-11ec-afcc-dda73bd1e3a0":
        response = requests.post(url, json=data)
        print(response)
        print(a["_id"])
        time.sleep(0.1) # Sleep for 1 seconds
# Out:
# <Response [201]>
# ac169680-5385-11ec-afcc-dda73bd1e3a0
# <Response [201]>
# ce198ee0-5385-11ec-afcc-dda73bd1e3a0
# <Response [201]>
# 3a933180-538a-11ec-afcc-dda73bd1e3a0
# <Response [201]>
# 5895fe60-538a-11ec-afcc-dda73bd1e3a0
# <Response [201]>
# 6dff4180-538a-11ec-afcc-dda73bd1e3a0
# <Response [201]>
# 94fd8e40-538a-11ec-afcc-dda73bd1e3a0
# <Response [201]>
# a69a8720-538a-11ec-afcc-dda73bd1e3a0
# <Response [201]>
# 5ec124f0-58d4-11ec-afcc-dda73bd1e3a0
# <Response [201]>
# 9cc63830-58d4-11ec-afcc-dda73bd1e3a0
# <Response [201]>
# b9b76e00-58d4-11ec-afcc-dda73bd1e3a0
# <Response [201]>
# 6029a3b0-58d6-11ec-afcc-dda73bd1e3a0
# <Response [201]>
# 16098440-58da-11ec-afcc-dda73bd1e3a0
# <Response [201]>
# 3b850190-58da-11ec-afcc-dda73bd1e3a0
# <Response [201]>
# 53466580-58da-11ec-afcc-dda73bd1e3a0
# <Response [201]>
# 8ecae860-58da-11ec-afcc-dda73bd1e3a0
# <Response [201]>
# a58eb270-58da-11ec-afcc-dda73bd1e3a0
# <Response [201]>
# b0eba1f0-58da-11ec-afcc-dda73bd1e3a0
# ...

# %%
import bson
from pymongo import MongoClient
import requests
import time
from bson.json_util import dumps
from bson.json_util import loads

con = MongoClient('mongodb://admin:J5B3NAzXttzS@35.180.134.166:27017/?authSource=CUN&readPreference=primary&appname=MongoDB%20Compass&ssl=false')
db = con['Secretos']
collection = db.secretos
cursor = collection.count_documents({ "$and": [{"userCompany": "619b766271a000f7820c2c77"},{"surveys.sequence": "3"}]})
#cursor = collection.find({"_id":"ae5182e0-d1eb-11ec-afcc-dda73bd1e3a0"}, {'file': False,'metadata': False,'surveys': False})
print(cursor)

#for a in cursor:
    #b=len(bson.BSON.encode(a))
    #print(b)
# Out:
# 246
